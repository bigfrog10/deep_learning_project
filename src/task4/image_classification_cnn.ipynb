# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import keras

# %%
# (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
# train_images, test_images = train_images / 255.0, test_images / 255.0

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
# (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data() 

train_images, test_images = train_images / 255.0, test_images / 255.0

print('Shape of x_train is {}'.format(train_images.shape))
print('Shape of x_test is {}'.format(train_labels.shape))
print('Shape of y_train is {}'.format(test_images.shape))
print('Shape of y_test is {}'.format(test_labels.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (50000, 1)
# Shape of y_train is (10000, 32, 32, 3)
# Shape of y_test is (10000, 1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))) # input shape 32x32 image with RGB (3)
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dropout(0.5)),
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.5)),
model.add(layers.Dense(10,activation='softmax'))

adam = keras.optimizers.Adam(learning_rate=0.0001)
# rmsprop = keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(optimizer=adam,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# model1=Sequential()
# model1.add(Conv2D(filters=32,kernel_size=(4,4),input_shape=(32,32,3),activation='relu'))
# model1.add(MaxPool2D(pool_size=(2,2)))
# model1.add(Conv2D(filters=32,kernel_size=(4,4),input_shape=(32,32,3),activation='relu'))
# model1.add(MaxPool2D(pool_size=(2,2)))
# model1.add(Flatten())
# model1.add(Dense(256,activation='relu'))
# model1.add(Dense(10,activation='softmax'))
# model1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_102 (Conv2D)             │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_70 (MaxPooling2D) │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_103 (Conv2D)             │ (None, 13, 13, 128)    │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_71 (MaxPooling2D) │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_104 (Conv2D)             │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_30 (Flatten)            │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_26 (Dropout)            │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 317,258 (1.21 MB)
#  Trainable params: 317,258 (1.21 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_images, train_labels, epochs=40, batch_size=64, 
                    validation_data=(test_images, test_labels))

# history = model.fit(train_images, train_labels, epochs=20, validation_split=0.2)

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print(test_acc)
# Out:
# Epoch 1/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6759 - loss: 0.9364 - val_accuracy: 0.7019 - val_loss: 0.8498
# Epoch 2/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.6781 - loss: 0.9318 - val_accuracy: 0.7082 - val_loss: 0.8396
# Epoch 3/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.6815 - loss: 0.9241 - val_accuracy: 0.7101 - val_loss: 0.8322
# Epoch 4/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6893 - loss: 0.8974 - val_accuracy: 0.7164 - val_loss: 0.8162
# Epoch 5/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6918 - loss: 0.8930 - val_accuracy: 0.7237 - val_loss: 0.8140
# Epoch 6/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6942 - loss: 0.8836 - val_accuracy: 0.7161 - val_loss: 0.8094
# Epoch 7/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6990 - loss: 0.8753 - val_accuracy: 0.7140 - val_loss: 0.8198
# Epoch 8/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7008 - loss: 0.8728 - val_accuracy: 0.7242 - val_loss: 0.7906
# Epoch 9/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7008 - loss: 0.8699 - val_accuracy: 0.7315 - val_loss: 0.7814
# Epoch 10/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7017 - loss: 0.8594 - val_accuracy: 0.7197 - val_loss: 0.8035
# Epoch 11/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7058 - loss: 0.8510 - val_accuracy: 0.7313 - val_loss: 0.7757
# Epoch 12/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.7097 - loss: 0.8421 - val_accuracy: 0.7351 - val_loss: 0.7714
# Epoch 13/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7111 - loss: 0.8400 - val_accuracy: 0.7252 - val_loss: 0.7901
# Epoch 14/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7147 - loss: 0.8310 - val_accuracy: 0.7355 - val_loss: 0.7652
# Epoch 15/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7182 - loss: 0.8203 - val_accuracy: 0.7344 - val_loss: 0.7763
# Epoch 16/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7191 - loss: 0.8228 - val_accuracy: 0.7219 - val_loss: 0.7929
# Epoch 17/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7234 - loss: 0.8018 - val_accuracy: 0.7346 - val_loss: 0.7718
# Epoch 18/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7240 - loss: 0.7941 - val_accuracy: 0.7416 - val_loss: 0.7471
# Epoch 19/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7280 - loss: 0.7887 - val_accuracy: 0.7441 - val_loss: 0.7426
# Epoch 20/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7328 - loss: 0.7881 - val_accuracy: 0.7439 - val_loss: 0.7379
# Epoch 21/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7295 - loss: 0.7855 - val_accuracy: 0.7444 - val_loss: 0.7425
# Epoch 22/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7339 - loss: 0.7744 - val_accuracy: 0.7511 - val_loss: 0.7372
# Epoch 23/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.7375 - loss: 0.7640 - val_accuracy: 0.7478 - val_loss: 0.7323
# Epoch 24/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7379 - loss: 0.7626 - val_accuracy: 0.7479 - val_loss: 0.7240
# Epoch 25/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7375 - loss: 0.7593 - val_accuracy: 0.7451 - val_loss: 0.7518
# Epoch 26/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7448 - loss: 0.7480 - val_accuracy: 0.7492 - val_loss: 0.7297
# Epoch 27/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7449 - loss: 0.7489 - val_accuracy: 0.7501 - val_loss: 0.7132
# Epoch 28/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7463 - loss: 0.7362 - val_accuracy: 0.7556 - val_loss: 0.7135
# Epoch 29/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7473 - loss: 0.7360 - val_accuracy: 0.7562 - val_loss: 0.7071
# Epoch 30/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7493 - loss: 0.7208 - val_accuracy: 0.7503 - val_loss: 0.7305
# Epoch 31/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.7529 - loss: 0.7248 - val_accuracy: 0.7569 - val_loss: 0.7101
# Epoch 32/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.7506 - loss: 0.7273 - val_accuracy: 0.7578 - val_loss: 0.6996
# Epoch 33/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7593 - loss: 0.7105 - val_accuracy: 0.7506 - val_loss: 0.7214
# Epoch 34/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.7580 - loss: 0.7018 - val_accuracy: 0.7618 - val_loss: 0.7043
# Epoch 35/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.7585 - loss: 0.7049 - val_accuracy: 0.7597 - val_loss: 0.7006
# Epoch 36/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.7604 - loss: 0.6944 - val_accuracy: 0.7551 - val_loss: 0.6979
# Epoch 37/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7644 - loss: 0.6809 - val_accuracy: 0.7574 - val_loss: 0.6995
# Epoch 38/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.7582 - loss: 0.6967 - val_accuracy: 0.7619 - val_loss: 0.6885
# Epoch 39/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.7674 - loss: 0.6763 - val_accuracy: 0.7576 - val_loss: 0.7005
# Epoch 40/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.7654 - loss: 0.6755 - val_accuracy: 0.7629 - val_loss: 0.6844
# 313/313 - 1s - 4ms/step - accuracy: 0.7629 - loss: 0.6844
# 0.7628999948501587

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)

# probability_model = tf.keras.Sequential([model,
#                                          tf.keras.layers.Softmax()])
predictions = model.predict(test_images)

print(predictions[0])
np.argmax(predictions[0])
print(test_labels[0])
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.7629 - loss: 0.6844
#
# Test accuracy: 0.7628999948501587
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# [2.8404625e-04 1.3354015e-04 4.1986383e-03 8.6635667e-01 8.4614183e-04
#  1.0205324e-01 2.4379618e-02 3.0319122e-04 1.2947754e-03 1.5000411e-04]
# [3]

# %%
def plot_image(j, predictions_array, true_label, img):
    true_label, img = true_label[j], img[j]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                         100*np.max(predictions_array),
                                         class_names[true_label[0]]),
               color=color)

def plot_value_array(k, predictions_array, true_label):
    true_label = true_label[k]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label[0]].set_color('blue')

i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions[i], test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
