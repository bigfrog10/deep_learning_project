# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from keras import layers
import matplotlib.pyplot as plt

# every file works, only the data distribution changes accordingly
df = pd.read_csv('fd01-sample1.csv')
print(df.Class.value_counts())
# df = pd.read_csv('fd01-sample2.csv')
# df = pd.read_csv('fd02-sample1.csv')
# df = pd.read_csv('fd02-sample2.csv')

# split into train and test dataset
x_train, x_test = train_test_split(df, test_size=0.2)
print(x_train.shape, x_test.shape)
print(x_test.Class.value_counts())

y = x_train.Class
x_train.drop(['Class'], axis=1)
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import preprocessing

# The following 2 scalers both work with the same accuracy
# scaler = MinMaxScaler()
# x = scaler.fit_transform(x_train)
# xt = scaler.transform(x_test)
scaler = StandardScaler()
x = scaler.fit_transform(x_train)
xt = scaler.transform(x_test)
# x = preprocessing.normalize(x_train)
# xt = preprocessing.normalize(x_test)

model = keras.Sequential()
model.add(layers.Input((30, )))
# model.add(layers.Dense(128, activation='relu', kernel_initializer='he_normal'))
# model.add(layers.Dropout(0.5))  # without dropping out, it will overfit
# model.add(layers.Dense(128, activation='relu'))
# model.add(layers.Dropout(0.5))  # without dropping out, it will overfit
model.add(layers.Dense(80, activation='relu'))
model.add(layers.Dropout(0.65))  # without dropping out, it will overfit
# model.add(layers.Dense(8, activation='relu'))
# model.add(layers.Dropout(0.5))  # without dropping out, it will overfit   
model.add(layers.Dense(1, activation='sigmoid'))

# adam = keras.optimizers.Adam(learning_rate=0.0001)
# model.compile(loss="binary_crossentropy", optimizer=adam, metrics=["accuracy"])
# model.compile(optimizer=adam, loss='mse', metrics=['accuracy'])
# model.compile(optimizer='sgd', loss='mse', metrics=[keras.metrics.BinaryAccuracy])
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

model.summary()
# Out:
# Class
# 0    508
# 1    492
# Name: count, dtype: int64
# (800, 30) (200, 30)
# Class
# 0    106
# 1     94
# Name: count, dtype: int64
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_46 (Dense)                │ (None, 80)             │         2,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 1)              │            81 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,561 (10.00 KB)
#  Trainable params: 2,561 (10.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
batch_size = 100
epochs = 100

history = model.fit(x_train, y, batch_size=batch_size, epochs=epochs, validation_split=0.1)

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5678 - loss: 0.3544 - val_accuracy: 0.7000 - val_loss: 0.1540
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6248 - loss: 0.3060 - val_accuracy: 0.8375 - val_loss: 0.1175
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6480 - loss: 0.2853 - val_accuracy: 0.8500 - val_loss: 0.1033
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6415 - loss: 0.2917 - val_accuracy: 0.8625 - val_loss: 0.1041
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6882 - loss: 0.2524 - val_accuracy: 0.8875 - val_loss: 0.1115
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7081 - loss: 0.2428 - val_accuracy: 0.8625 - val_loss: 0.1130
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7556 - loss: 0.2035 - val_accuracy: 0.8625 - val_loss: 0.1112
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7473 - loss: 0.2145 - val_accuracy: 0.8750 - val_loss: 0.1028
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7444 - loss: 0.2178 - val_accuracy: 0.8750 - val_loss: 0.0994
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7746 - loss: 0.1978 - val_accuracy: 0.8750 - val_loss: 0.0975
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7709 - loss: 0.2095 - val_accuracy: 0.8875 - val_loss: 0.1028
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.1998 - val_accuracy: 0.9000 - val_loss: 0.1060
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7958 - loss: 0.1844 - val_accuracy: 0.9000 - val_loss: 0.1064
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7566 - loss: 0.2056 - val_accuracy: 0.9000 - val_loss: 0.1058
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8042 - loss: 0.1756 - val_accuracy: 0.9000 - val_loss: 0.1036
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7832 - loss: 0.1963 - val_accuracy: 0.9000 - val_loss: 0.1004
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8246 - loss: 0.1581 - val_accuracy: 0.9000 - val_loss: 0.0988
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.1017 - val_accuracy: 0.9375 - val_loss: 0.0619
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8890 - loss: 0.1012 - val_accuracy: 0.9375 - val_loss: 0.0613
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8951 - loss: 0.0975 - val_accuracy: 0.9375 - val_loss: 0.0609
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9068 - loss: 0.0915 - val_accuracy: 0.9375 - val_loss: 0.0601
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9010 - loss: 0.0972 - val_accuracy: 0.9375 - val_loss: 0.0593
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9017 - loss: 0.0883 - val_accuracy: 0.9375 - val_loss: 0.0589
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9093 - loss: 0.0898 - val_accuracy: 0.9375 - val_loss: 0.0595
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9050 - loss: 0.0894 - val_accuracy: 0.9375 - val_loss: 0.0597
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.0845 - val_accuracy: 0.9375 - val_loss: 0.0598
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.0886 - val_accuracy: 0.9375 - val_loss: 0.0599
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.0919 - val_accuracy: 0.9375 - val_loss: 0.0594
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.0828 - val_accuracy: 0.9375 - val_loss: 0.0592
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9066 - loss: 0.0909 - val_accuracy: 0.9375 - val_loss: 0.0592
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9050 - loss: 0.0906 - val_accuracy: 0.9375 - val_loss: 0.0592
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9118 - loss: 0.0818 - val_accuracy: 0.9375 - val_loss: 0.0588
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9233 - loss: 0.0710 - val_accuracy: 0.9375 - val_loss: 0.0587
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9288 - loss: 0.0688 - val_accuracy: 0.9375 - val_loss: 0.0586
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9098 - loss: 0.0842 - val_accuracy: 0.9375 - val_loss: 0.0585
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9237 - loss: 0.0731 - val_accuracy: 0.9375 - val_loss: 0.0582
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9181 - loss: 0.0803 - val_accuracy: 0.9375 - val_loss: 0.0573
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9100 - loss: 0.0824 - val_accuracy: 0.9375 - val_loss: 0.0558
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9315 - loss: 0.0662 - val_accuracy: 0.9375 - val_loss: 0.0547
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9301 - loss: 0.0655 - val_accuracy: 0.9500 - val_loss: 0.0454
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9210 - loss: 0.0747 - val_accuracy: 0.9500 - val_loss: 0.0442
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8903 - loss: 0.1007 - val_accuracy: 0.9500 - val_loss: 0.0447
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9034 - loss: 0.0867 - val_accuracy: 0.9500 - val_loss: 0.0456
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.0678 - val_accuracy: 0.9500 - val_loss: 0.0459
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9279 - loss: 0.0677 - val_accuracy: 0.9500 - val_loss: 0.0418
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9228 - loss: 0.0776 - val_accuracy: 0.9625 - val_loss: 0.0349
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9284 - loss: 0.0703 - val_accuracy: 0.9625 - val_loss: 0.0355
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9374 - loss: 0.0583 - val_accuracy: 0.9500 - val_loss: 0.0440
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.0704 - val_accuracy: 0.9500 - val_loss: 0.0443
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9381 - loss: 0.0626 - val_accuracy: 0.9625 - val_loss: 0.0330
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9192 - loss: 0.0759 - val_accuracy: 0.9625 - val_loss: 0.0329
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9348 - loss: 0.0584 - val_accuracy: 0.9625 - val_loss: 0.0332
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9306 - loss: 0.0652 - val_accuracy: 0.9500 - val_loss: 0.0375
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9313 - loss: 0.0706 - val_accuracy: 0.9625 - val_loss: 0.0327
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9263 - loss: 0.0676 - val_accuracy: 0.9625 - val_loss: 0.0322
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9403 - loss: 0.0601 - val_accuracy: 0.9625 - val_loss: 0.0316
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
y = model.predict(xt)

# import seaborn as sns
# sns.catplot(x=x[:, 0], y=model.labels_)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

cm = confusion_matrix(x_test.iloc[:, 0], np.where(y > 0.5, 1, 0))
print(cm)
plt.figure(figsize=(16, 14))
sns.heatmap(cm, annot=True, fmt='d', annot_kws={'size': 20})

plt.show()

# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.labels_)
# disp.plot()
# plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[106   0]
#  [ 16  78]]
